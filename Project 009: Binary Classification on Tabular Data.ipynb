# %% [markdown]
# <a href="https://colab.research.google.com/github/Aqfa07/ML-Project/blob/main/Project%20009%3A%20Binary%20Classification%20on%20Tabular%20Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Load data
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
cols = ["Pregnancies", "Glucose", "BloodPressure", "SkinThickness", "Insulin",
        "BMI", "DiabetesPedigreeFunction", "Age", "Outcome"]
df = pd.read_csv(url, names=cols)

# Check class distribution
print("Class distribution:\n", df['Outcome'].value_counts())

# Split and scale
X = df.drop("Outcome", axis=1).values
y = df["Outcome"].values
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Callbacks
early_stop = EarlyStopping(patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(factor=0.2, patience=5)

# Build model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(16, activation='relu', input_shape=[X.shape[1]]),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy', tf.keras.metrics.AUC()])

# Train
history = model.fit(X_train, y_train,
                    epochs=100,
                    validation_split=0.1,
                    callbacks=[early_stop, reduce_lr],
                    verbose=1)

# Evaluate
loss, acc, auc = model.evaluate(X_test, y_test)
print(f"\nTest Accuracy: {acc:.4f}")
print(f"Test AUC: {auc:.4f}")

# Classification report
y_pred = (model.predict(X_test) > 0.5).astype(int)
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Class distribution:
#  Outcome
# 0    500
# 1    268
# Name: count, dtype: int64
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 170ms/step - accuracy: 0.5142 - auc: 0.4883 - loss: 0.7327 - val_accuracy: 0.5806 - val_auc: 0.4903 - val_loss: 0.6914 - learning_rate: 0.0010
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5769 - auc: 0.5165 - loss: 0.6935 - val_accuracy: 0.5968 - val_auc: 0.5476 - val_loss: 0.6775 - learning_rate: 0.0010
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6052 - auc: 0.5544 - loss: 0.6690 - val_accuracy: 0.6129 - val_auc: 0.5908 - val_loss: 0.6677 - learning_rate: 0.0010
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6416 - auc: 0.5890 - loss: 0.6486 - val_accuracy: 0.6290 - val_auc: 0.6270 - val_loss: 0.6584 - learning_rate: 0.0010
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6557 - auc: 0.6331 - loss: 0.6270 - val_accuracy: 0.6613 - val_auc: 0.6584 - val_loss: 0.6493 - learning_rate: 0.0010
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6657 - auc: 0.6383 - loss: 0.6237 - val_accuracy: 0.6452 - val_auc: 0.6919 - val_loss: 0.6399 - learning_rate: 0.0010
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6634 - auc: 0.6720 - loss: 0.6115 - val_accuracy: 0.6452 - val_auc: 0.7103 - val_loss: 0.6324 - learning_rate: 0.0010
# Epoch 8/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6833 - auc: 0.7314 - loss: 0.5849 - val_accuracy: 0.6290 - val_auc: 0.7162 - val_loss: 0.6260 - learning_rate: 0.0010
# Epoch 9/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6836 - auc: 0.6963 - loss: 0.6014 - val_accuracy: 0.6452 - val_auc: 0.7330 - val_loss: 0.6172 - learning_rate: 0.0010
# Epoch 10/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6753 - auc: 0.7148 - loss: 0.5727 - val_accuracy: 0.6774 - val_auc: 0.7438 - val_loss: 0.6097 - learning_rate: 0.0010
# Epoch 11/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7195 - auc: 0.7268 - loss: 0.5671 - val_accuracy: 0.6935 - val_auc: 0.7514 - val_loss: 0.6023 - learning_rate: 0.0010
# Epoch 12/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6818 - auc: 0.6933 - loss: 0.5820 - val_accuracy: 0.7097 - val_auc: 0.7616 - val_loss: 0.5957 - learning_rate: 0.0010
# Epoch 13/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7039 - auc: 0.7230 - loss: 0.5741 - val_accuracy: 0.7097 - val_auc: 0.7659 - val_loss: 0.5887 - learning_rate: 0.0010
# Epoch 14/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7053 - auc: 0.7521 - loss: 0.5607 - val_accuracy: 0.7097 - val_auc: 0.7768 - val_loss: 0.5836 - learning_rate: 0.0010
# Epoch 15/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7357 - auc: 0.7442 - loss: 0.5556 - val_accuracy: 0.6935 - val_auc: 0.7789 - val_loss: 0.5778 - learning_rate: 0.0010
# Epoch 16/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6844 - auc: 0.7557 - loss: 0.5539 - val_accuracy: 0.7097 - val_auc: 0.7784 - val_loss: 0.5720 - learning_rate: 0.0010
# Epoch 17/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7265 - auc: 0.7541 - loss: 0.5081 - val_accuracy: 0.7419 - val_auc: 0.7838 - val_loss: 0.5663 - learning_rate: 0.0010
# Epoch 18/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7191 - auc: 0.7784 - loss: 0.5462 - val_accuracy: 0.7258 - val_auc: 0.7865 - val_loss: 0.5597 - learning_rate: 0.0010
# Epoch 19/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7788 - auc: 0.8234 - loss: 0.4810 - val_accuracy: 0.7258 - val_auc: 0.7897 - val_loss: 0.5554 - learning_rate: 0.0010
# Epoch 20/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7159 - auc: 0.7897 - loss: 0.5143 - val_accuracy: 0.7419 - val_auc: 0.7957 - val_loss: 0.5503 - learning_rate: 0.0010
# Epoch 21/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6954 - auc: 0.7652 - loss: 0.5558 - val_accuracy: 0.7742 - val_auc: 0.7978 - val_loss: 0.5453 - learning_rate: 0.0010
# Epoch 22/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7526 - auc: 0.8134 - loss: 0.5083 - val_accuracy: 0.7742 - val_auc: 0.8049 - val_loss: 0.5411 - learning_rate: 0.0010
# Epoch 23/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7555 - auc: 0.7971 - loss: 0.4946 - val_accuracy: 0.7742 - val_auc: 0.8081 - val_loss: 0.5361 - learning_rate: 0.0010
# Epoch 24/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7433 - auc: 0.8226 - loss: 0.4911 - val_accuracy: 0.7581 - val_auc: 0.8086 - val_loss: 0.5326 - learning_rate: 0.0010
# Epoch 25/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7970 - auc: 0.8200 - loss: 0.4863 - val_accuracy: 0.7903 - val_auc: 0.8124 - val_loss: 0.5318 - learning_rate: 0.0010
# Epoch 26/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7864 - auc: 0.8129 - loss: 0.4975 - val_accuracy: 0.7903 - val_auc: 0.8130 - val_loss: 0.5301 - learning_rate: 0.0010
# Epoch 27/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7606 - auc: 0.8091 - loss: 0.4897 - val_accuracy: 0.7742 - val_auc: 0.8103 - val_loss: 0.5318 - learning_rate: 0.0010
# Epoch 28/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7516 - auc: 0.8108 - loss: 0.4990 - val_accuracy: 0.7742 - val_auc: 0.8086 - val_loss: 0.5314 - learning_rate: 0.0010
# Epoch 29/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7224 - auc: 0.8180 - loss: 0.4919 - val_accuracy: 0.7742 - val_auc: 0.8081 - val_loss: 0.5326 - learning_rate: 0.0010
# Epoch 30/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7890 - auc: 0.8599 - loss: 0.4564 - val_accuracy: 0.7742 - val_auc: 0.8092 - val_loss: 0.5325 - learning_rate: 0.0010
# Epoch 31/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7542 - auc: 0.8187 - loss: 0.4796 - val_accuracy: 0.7742 - val_auc: 0.8097 - val_loss: 0.5316 - learning_rate: 0.0010
# Epoch 32/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7727 - auc: 0.8165 - loss: 0.4843 - val_accuracy: 0.7742 - val_auc: 0.8108 - val_loss: 0.5312 - learning_rate: 2.0000e-04
# Epoch 33/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7669 - auc: 0.8298 - loss: 0.4619 - val_accuracy: 0.7742 - val_auc: 0.8108 - val_loss: 0.5308 - learning_rate: 2.0000e-04
# Epoch 34/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7646 - auc: 0.8334 - loss: 0.4662 - val_accuracy: 0.7742 - val_auc: 0.8103 - val_loss: 0.5302 - learning_rate: 2.0000e-04
# Epoch 35/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7490 - auc: 0.8155 - loss: 0.4814 - val_accuracy: 0.7581 - val_auc: 0.8086 - val_loss: 0.5300 - learning_rate: 2.0000e-04
# Epoch 36/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7900 - auc: 0.8387 - loss: 0.4669 - val_accuracy: 0.7581 - val_auc: 0.8103 - val_loss: 0.5297 - learning_rate: 2.0000e-04
# Epoch 37/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7590 - auc: 0.8177 - loss: 0.5075 - val_accuracy: 0.7581 - val_auc: 0.8103 - val_loss: 0.5295 - learning_rate: 2.0000e-04
# Epoch 38/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7623 - auc: 0.8294 - loss: 0.4759 - val_accuracy: 0.7581 - val_auc: 0.8114 - val_loss: 0.5298 - learning_rate: 2.0000e-04
# Epoch 39/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7638 - auc: 0.8224 - loss: 0.4904 - val_accuracy: 0.7581 - val_auc: 0.8114 - val_loss: 0.5300 - learning_rate: 2.0000e-04
# Epoch 40/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7533 - auc: 0.8279 - loss: 0.4901 - val_accuracy: 0.7581 - val_auc: 0.8103 - val_loss: 0.5293 - learning_rate: 2.0000e-04
# Epoch 41/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7603 - auc: 0.8303 - loss: 0.4923 - val_accuracy: 0.7581 - val_auc: 0.8097 - val_loss: 0.5294 - learning_rate: 2.0000e-04
# Epoch 42/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7514 - auc: 0.8319 - loss: 0.5029 - val_accuracy: 0.7581 - val_auc: 0.8108 - val_loss: 0.5288 - learning_rate: 2.0000e-04
# Epoch 43/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7830 - auc: 0.8142 - loss: 0.4891 - val_accuracy: 0.7581 - val_auc: 0.8103 - val_loss: 0.5294 - learning_rate: 2.0000e-04
# Epoch 44/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7555 - auc: 0.8001 - loss: 0.5390 - val_accuracy: 0.7581 - val_auc: 0.8108 - val_loss: 0.5289 - learning_rate: 2.0000e-04
# Epoch 45/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7752 - auc: 0.8345 - loss: 0.4728 - val_accuracy: 0.7581 - val_auc: 0.8108 - val_loss: 0.5292 - learning_rate: 2.0000e-04
# Epoch 46/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7819 - auc: 0.8492 - loss: 0.4499 - val_accuracy: 0.7581 - val_auc: 0.8108 - val_loss: 0.5290 - learning_rate: 2.0000e-04
# Epoch 47/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7565 - auc: 0.8232 - loss: 0.4723 - val_accuracy: 0.7581 - val_auc: 0.8108 - val_loss: 0.5287 - learning_rate: 2.0000e-04
# Epoch 48/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7560 - auc: 0.8207 - loss: 0.4842 - val_accuracy: 0.7581 - val_auc: 0.8114 - val_loss: 0.5287 - learning_rate: 4.0000e-05
# Epoch 49/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7433 - auc: 0.7950 - loss: 0.5195 - val_accuracy: 0.7581 - val_auc: 0.8108 - val_loss: 0.5287 - learning_rate: 4.0000e-05
# Epoch 50/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7499 - auc: 0.8184 - loss: 0.4782 - val_accuracy: 0.7581 - val_auc: 0.8114 - val_loss: 0.5287 - learning_rate: 4.0000e-05
# Epoch 51/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7393 - auc: 0.8000 - loss: 0.5098 - val_accuracy: 0.7581 - val_auc: 0.8114 - val_loss: 0.5286 - learning_rate: 4.0000e-05
# Epoch 52/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7621 - auc: 0.8264 - loss: 0.4774 - val_accuracy: 0.7581 - val_auc: 0.8114 - val_loss: 0.5286 - learning_rate: 4.0000e-05
# Epoch 53/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7549 - auc: 0.8021 - loss: 0.5007 - val_accuracy: 0.7581 - val_auc: 0.8114 - val_loss: 0.5285 - learning_rate: 4.0000e-05
# Epoch 54/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7657 - auc: 0.8292 - loss: 0.4787 - val_accuracy: 0.7581 - val_auc: 0.8108 - val_loss: 0.5285 - learning_rate: 4.0000e-05
# Epoch 55/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7719 - auc: 0.8268 - loss: 0.4733 - val_accuracy: 0.7581 - val_auc: 0.8114 - val_loss: 0.5284 - learning_rate: 4.0000e-05
# Epoch 56/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7487 - auc: 0.8088 - loss: 0.4969 - val_accuracy: 0.7581 - val_auc: 0.8114 - val_loss: 0.5284 - learning_rate: 4.0000e-05
# Epoch 57/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7723 - auc: 0.8483 - loss: 0.4632 - val_accuracy: 0.7581 - val_auc: 0.8108 - val_loss: 0.5284 - learning_rate: 4.0000e-05
# Epoch 58/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7453 - auc: 0.8194 - loss: 0.5073 - val_accuracy: 0.7581 - val_auc: 0.8114 - val_loss: 0.5282 - learning_rate: 4.0000e-05
# Epoch 59/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7516 - auc: 0.8204 - loss: 0.4798 - val_accuracy: 0.7581 - val_auc: 0.8114 - val_loss: 0.5282 - learning_rate: 4.0000e-05
# Epoch 60/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7782 - auc: 0.8272 - loss: 0.4883 - val_accuracy: 0.7581 - val_auc: 0.8114 - val_loss: 0.5282 - learning_rate: 4.0000e-05
# Epoch 61/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7565 - auc: 0.8332 - loss: 0.4894 - val_accuracy: 0.7581 - val_auc: 0.8114 - val_loss: 0.5282 - learning_rate: 4.0000e-05
# Epoch 62/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7663 - auc: 0.8195 - loss: 0.4802 - val_accuracy: 0.7581 - val_auc: 0.8114 - val_loss: 0.5281 - learning_rate: 4.0000e-05
# Epoch 63/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7418 - auc: 0.8008 - loss: 0.5179 - val_accuracy: 0.7581 - val_auc: 0.8114 - val_loss: 0.5280 - learning_rate: 4.0000e-05
# Epoch 64/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7901 - auc: 0.8449 - loss: 0.4513 - val_accuracy: 0.7581 - val_auc: 0.8108 - val_loss: 0.5280 - learning_rate: 4.0000e-05
# Epoch 65/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7724 - auc: 0.8293 - loss: 0.4878 - val_accuracy: 0.7581 - val_auc: 0.8108 - val_loss: 0.5279 - learning_rate: 4.0000e-05
# Epoch 66/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7487 - auc: 0.8197 - loss: 0.4978 - val_accuracy: 0.7581 - val_auc: 0.8114 - val_loss: 0.5278 - learning_rate: 4.0000e-05
# Epoch 67/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7536 - auc: 0.8140 - loss: 0.4871 - val_accuracy: 0.7581 - val_auc: 0.8114 - val_loss: 0.5278 - learning_rate: 4.0000e-05
# Epoch 68/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7623 - auc: 0.8177 - loss: 0.4769 - val_accuracy: 0.7581 - val_auc: 0.8108 - val_loss: 0.5279 - learning_rate: 4.0000e-05
# Epoch 69/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7682 - auc: 0.8435 - loss: 0.4659 - val_accuracy: 0.7581 - val_auc: 0.8108 - val_loss: 0.5279 - learning_rate: 4.0000e-05
# Epoch 70/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7774 - auc: 0.8404 - loss: 0.4606 - val_accuracy: 0.7581 - val_auc: 0.8108 - val_loss: 0.5280 - learning_rate: 4.0000e-05
# Epoch 71/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7400 - auc: 0.8125 - loss: 0.4963 - val_accuracy: 0.7581 - val_auc: 0.8114 - val_loss: 0.5281 - learning_rate: 4.0000e-05
# Epoch 72/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7417 - auc: 0.8064 - loss: 0.5051 - val_accuracy: 0.7581 - val_auc: 0.8114 - val_loss: 0.5281 - learning_rate: 8.0000e-06
# Epoch 73/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7470 - auc: 0.8287 - loss: 0.4874 - val_accuracy: 0.7581 - val_auc: 0.8114 - val_loss: 0.5281 - learning_rate: 8.0000e-06
# Epoch 74/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7919 - auc: 0.8585 - loss: 0.4541 - val_accuracy: 0.7581 - val_auc: 0.8114 - val_loss: 0.5281 - learning_rate: 8.0000e-06
# Epoch 75/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7597 - auc: 0.8012 - loss: 0.4903 - val_accuracy: 0.7581 - val_auc: 0.8114 - val_loss: 0.5281 - learning_rate: 8.0000e-06
# Epoch 76/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7602 - auc: 0.8399 - loss: 0.4715 - val_accuracy: 0.7581 - val_auc: 0.8114 - val_loss: 0.5281 - learning_rate: 8.0000e-06
# Epoch 77/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7458 - auc: 0.8153 - loss: 0.5075 - val_accuracy: 0.7581 - val_auc: 0.8114 - val_loss: 0.5281 - learning_rate: 1.6000e-06
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 190ms/step - accuracy: 0.6947 - auc: 0.7904 - loss: 0.5251
#
# Test Accuracy: 0.7468
# Test AUC: 0.8149
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.80      0.80        99
#            1       0.64      0.65      0.65        55
#
#     accuracy                           0.75       154
#    macro avg       0.72      0.73      0.73       154
# weighted avg       0.75      0.75      0.75       154
